# %%
# HCP YA data split

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold

df = pd.read_csv('/home/jovyan/nh26_td_gamb_diff_FC_best/HCP_YA_subjects_2026_07_20_14_29_24.csv')
diffusion_sub = pd.read_csv('/home/jovyan/nh26_td_gamb_diff_FC_best/diffusion_subjects.csv')
fmri_sub = pd.read_csv('/home/jovyan/nh26_td_gamb_diff_FC_best/with_gambling.csv')

# # Filter to subjects with full 3T completion
df_filtered = df[df['3T_Full_MR_Compl'] == True].copy()
print(f"Original N: {len(df)}")
print(f"Filtered N (3T complete): {len(df_filtered)}")

diffusion_ids = set(diffusion_sub['subjectID'])
fmri_ids = set(fmri_sub['0'])

df_final = df_filtered[
    df_filtered['Subject'].isin(diffusion_ids) & df_filtered['Subject'].isin(fmri_ids)
].copy()

print(f"3T complete N: {len(df_filtered)}")
print(f"Diffusion available N: {len(diffusion_ids)}")
print(f"fMRI/gambling available N: {len(fmri_ids)}")
print(f"Final N (all three criteria met): {len(df_final)}")
# Out:
# Original N: 1206
# Filtered N (3T complete): 889
# 3T complete N: 889
# Diffusion available N: 1041
# fMRI/gambling available N: 1084
# Final N (all three criteria met): 866

# %%
df_final['age_group'] = df_final['Age'].astype(str).str.strip()
df_final['strata'] = df_final['age_group'] + '_' + df_final['Gender'].astype(str)

print(df_final['strata'].value_counts())
print(f"\nNumber of unique strata: {df_final['strata'].nunique()}")
# Out:
# strata
# 26-30_F    202
# 31-35_F    177
# 26-30_M    175
# 22-25_M    123
# 31-35_M    109
# 22-25_F     71
# 36+_F        6
# 36+_M        3
# Name: count, dtype: int64
#
# Number of unique strata: 8

# %%
train_df, test_df = train_test_split(
    df_final,
    test_size=0.2,
    stratify=df_final['strata'],
    random_state=42
)

print(f"Train N: {len(train_df)}, Test N: {len(test_df)}")
print("\nTrain strata counts:")
print(train_df['strata'].value_counts())
print("\nTest strata counts:")
print(test_df['strata'].value_counts())
# Out:
# Train N: 692, Test N: 174
#
# Train strata counts:
# strata
# 26-30_F    161
# 31-35_F    142
# 26-30_M    140
# 22-25_M     98
# 31-35_M     87
# 22-25_F     57
# 36+_F        5
# 36+_M        2
# Name: count, dtype: int64
#
# Test strata counts:
# strata
# 26-30_F    41
# 31-35_F    35
# 26-30_M    35
# 22-25_M    25
# 31-35_M    22
# 22-25_F    14
# 36+_M       1
# 36+_F       1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

train_prop = train_df['strata'].value_counts(normalize=True).sort_index()
test_prop = test_df['strata'].value_counts(normalize=True).sort_index()

comparison = pd.DataFrame({'train': train_prop, 'test': test_prop})
print(comparison)
# Out:
#             train      test
# strata
# 22-25_F  0.082370  0.080460
# 22-25_M  0.141618  0.143678
# 26-30_F  0.232659  0.235632
# 26-30_M  0.202312  0.201149
# 31-35_F  0.205202  0.201149
# 31-35_M  0.125723  0.126437
# 36+_F    0.007225  0.005747
# 36+_M    0.002890  0.005747

# %%
print(train_df)
# Out:
#       Subject Release Acquisition Gender    Age  3T_Full_MR_Compl  \
# 347    163129      Q3         Q04      M  26-30              True
# 687    308129    S900         Q11      M  22-25              True
# 839    529953    S900         Q10      M  26-30              True
# 835    523032    S900         Q09      M  31-35              True
# 24     103818      Q1         Q01      F  31-35              True
# ...       ...     ...         ...    ...    ...               ...
# 469    187547    S500         Q06      F  31-35              True
# 1191   978578      Q3         Q04      F  31-35              True
# 564    205725      Q2         Q02      F  22-25              True
# 454    185038   S1200         Q11      M  31-35              True
# 529    199150      Q1         Q01      F  26-30              True
#
#       7T_Full_MR_Compl  MEG_FullProt_Compl age_group   strata
# 347              False               False     26-30  26-30_M
# 687              False               False     22-25  22-25_M
# 839              False               False     26-30  26-30_M
# 835              False               False     31-35  31-35_M
# 24               False               False     31-35  31-35_F
# ...                ...                 ...       ...      ...
# 469              False               False     31-35  31-35_F
# 1191             False               False     31-35  31-35_F
# 564              False               False     22-25  22-25_F
# 454              False               False     31-35  31-35_M
# 529              False               False     26-30  26-30_F
#
# [692 rows x 10 columns]

# %%
# Reset index for clean row numbers
train_df = train_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

# Save training set
train_df.to_csv('/home/jovyan/nh26_td_gamb_diff_FC_best/train_split.csv', index=False)

# Save test set
test_df.to_csv('/home/jovyan/nh26_td_gamb_diff_FC_best/test_split.csv', index=False)

print(f"Train saved: {len(train_df)} subjects")
print(f"Test saved: {len(test_df)} subjects")
# Out:
# Train saved: 692 subjects
# Test saved: 174 subjects
