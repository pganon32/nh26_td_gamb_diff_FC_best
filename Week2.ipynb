# %%
from pathlib import Path
from cloudpathlib import S3Path, S3Client

# Make sure that we have a cache path:
cache_path = Path('/tmp/cache')
if not cache_path.exists():
    cache_path.mkdir()

hcp_base_path = S3Path(
    's3://hcp-openaccess/HCP_1200/',
    client=S3Client(
        local_cache_dir=cache_path,
        profile_name='hcp'))

# %%
hcp_subdirs = list(hcp_base_path.iterdir())
# There are about 1200 of these, so we won't show them all, just the first 10:
hcp_subdirs[:10]
# Out:
# [S3Path('s3://hcp-openaccess/HCP_1200/100206'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100307'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100408'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100610'),
#  S3Path('s3://hcp-openaccess/HCP_1200/101006'),
#  S3Path('s3://hcp-openaccess/HCP_1200/101107'),
#  S3Path('s3://hcp-openaccess/HCP_1200/101309'),
#  S3Path('s3://hcp-openaccess/HCP_1200/101410'),
#  S3Path('s3://hcp-openaccess/HCP_1200/101915'),
#  S3Path('s3://hcp-openaccess/HCP_1200/102008')]

# %%
sub_path = hcp_base_path / '100206'
list(sub_path.iterdir())
# Out:
# [S3Path('s3://hcp-openaccess/HCP_1200/100206/.xdlm'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/MNINonLinear'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/T1w'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/release-notes'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/unprocessed')]

# %%
#sub_freesurfer_path = hcp_base_path / '100206' / 'T1w' / '100206'
#list(sub_freesurfer_path.iterdir())
# Out:
# [S3Path('s3://hcp-openaccess/HCP_1200/100206/T1w/100206/label'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/T1w/100206/mri'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/T1w/100206/stats'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/T1w/100206/surf'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/T1w/100206/touch')]

# %%
sub_id = '100206'
#t1_path = hcp_base_path / sub_id / 'T1w'
task_path = hcp_base_path / sub_id / 'MNINonLinear'
list(task_path.iterdir())
# Out:
# [S3Path('s3://hcp-openaccess/HCP_1200/100206/MNINonLinear/Native'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/MNINonLinear/ROIs'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/MNINonLinear/Results'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/MNINonLinear/fsaverage_LR32k'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/MNINonLinear/xfms'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/MNINonLinear/100206.164k_fs_LR.wb.spec'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/MNINonLinear/100206.ArealDistortion_FS.164k_fs_LR.dscalar.nii'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/MNINonLinear/100206.ArealDistortion_MSMAll.164k_fs_LR.dscalar.nii'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/MNINonLinear/100206.ArealDistortion_MSMSulc.164k_fs_LR.dscalar.nii'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/MNINonLinear/100206.BA.164k_fs_LR.dlabel.nii'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/MNINonLinear/100206.EdgeDistortion_MSMAll.164k_fs_LR.dscalar.nii'),
# ...

# %%
from utilities import crawl
diffusion_path = hcp_base_path / '100206' / 'T1w' / 'Diffusion.bedpostX'
list(diffusion_path.iterdir())
# Out:
# [S3Path('s3://hcp-openaccess/HCP_1200/100206/T1w/Diffusion.bedpostX/logs'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/T1w/Diffusion.bedpostX/xfms'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/T1w/Diffusion.bedpostX/bvals'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/T1w/Diffusion.bedpostX/bvecs'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/T1w/Diffusion.bedpostX/commands.txt'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/T1w/Diffusion.bedpostX/dyads1.nii.gz'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/T1w/Diffusion.bedpostX/dyads1_dispersion.nii.gz'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/T1w/Diffusion.bedpostX/dyads2.nii.gz'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/T1w/Diffusion.bedpostX/dyads2_dispersion.nii.gz'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/T1w/Diffusion.bedpostX/dyads2_thr0.05.nii.gz'),
#  S3Path('s3://hcp-openaccess/HCP_1200/100206/T1w/Diffusion.bedpostX/dyads2_thr0.05_modf2.nii.gz'),
# ...

# %%
diffusion_bvecs = hcp_base_path / '100206' / 'T1w' / 'Diffusion' / 'bvecs'

with diffusion_bvecs.open('r') as f:
    content = f.read()
print(content)
# Out:
#  -0.542186   0.918106  -0.382921   0.097977   0.204410  -0.420482  -0.713198   0.337916   0.595529   0.902882   0.172680   0.258874   0.845580   0.409899   0.976789   0.293249  -0.542752   0.902900   0.424887   0.104118   0.754053   0.542995   0.188334   0.791947   0.304834   0.697999   0.438156   0.793026   0.307747   0.486607   0.867470   0.516189   0.543239   0.299074   0.593076   0.619700   0.220479   0.235762   0.844673   0.900421   0.284420   0.031790   0.571379   0.833420   0.244202  -0.003766   0.795861   0.999893   0.543458   0.040432   0.948777   0.074647   0.643578   0.058086   0.166397   0.665435   0.448909   0.442191   0.649559   0.678402   0.051182   0.582544   0.585146   0.750801   0.543328   0.131552   0.601377   0.676446   0.992241   0.069078   0.835667   0.258221   0.412554   0.913091   0.614133  -0.757527   0.267939   0.572262   0.128238   0.347430   0.541318   0.847558   0.337305   0.542391   0.663110   0.930699   0.078221   0.172307   0.536620   0.560125   0.5268
# ...
