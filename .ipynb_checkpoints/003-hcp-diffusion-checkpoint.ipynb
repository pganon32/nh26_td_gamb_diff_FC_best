# %% [markdown]
# # Diffusion MRI data and derivatives in the Human Connectome Project

# %% [markdown]
# ## Diffusion MRI
#
# Diffusion MRI uses directionally oriented gradients and a pulsed gradient scan sequence to sensitize the MRI measurement to location- and direction-specific random diffusion of water.
#
# This is useful because in locations where the tissue is densely packed, diffusion of water is restricted. In locations where tissue is oriented (e.g., in axonal bundles) diffusion is less restricted along the length of the bundles than across their boundaries providing a cue for computational tractography methods.
#
# ![](images/diffusion.jpg)

# %%
from pathlib import Path

# Make the path object:
cache_path = Path('/tmp/cache')

# Just because we have made a cache path object doesn't mean that the directory
# we made exists; here we check if it exists and make the directory if not.
if not cache_path.exists():
    cache_path.mkdir()

# %%
from utilities import ls, crawl
import nibabel as nib

# %%
from cloudpathlib import S3Path, S3Client

client = S3Client(
    local_cache_dir=cache_path,
    profile_name="hcp")

hcp_base_path = S3Path(
    "s3://hcp-openaccess/",
    client=client)
# Out:
# /srv/conda/envs/notebook/lib/python3.10/site-packages/google/api_core/_python_version_support.py:255: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)

# %%
ls(hcp_base_path)
# Out:
# [S3Path('s3://hcp-openaccess/HCP'),
#  S3Path('s3://hcp-openaccess/HCP_1200'),
#  S3Path('s3://hcp-openaccess/HCP_900'),
#  S3Path('s3://hcp-openaccess/HCP_Resources'),
#  S3Path('s3://hcp-openaccess/HCP_Retest'),
#  S3Path('s3://hcp-openaccess/HCP_WB_Tutorial_1.0')]

# %%
# ls(hcp_base_path / "HCP_1200")

# %%
crawl(hcp_base_path / "HCP_1200" / "100206" / "T1w" / "Diffusion")
# Out:
# Diffusion
#    eddylogs
#       eddy_unwarped_images.eddy_movement_rms
#       eddy_unwarped_images.eddy_outlier_map
#       eddy_unwarped_images.eddy_outlier_n_sqr_stdev_map
#       eddy_unwarped_images.eddy_outlier_n_stdev_map
#       eddy_unwarped_images.eddy_outlier_report
#       eddy_unwarped_images.eddy_parameters
#       eddy_unwarped_images.eddy_post_eddy_shell_alignment_parameters
#       eddy_unwarped_images.eddy_restricted_movement_rms
#    bvals
#    bvecs
#    data.nii.gz
#    grad_dev.nii.gz
#    nodif_brain_mask.nii.gz

# %%
diffusion_100206 = hcp_base_path / "HCP_1200" / "100206" / "T1w" / "Diffusion" / "data.nii.gz"

# %%
img_100206 = nib.load(diffusion_100206.fspath)

# %%
# Careful! This requires a lot of memory!
# img_100206.get_fdata()

# %% [markdown]
# ## HCP tractometry derivatives
#
# Tractometry assesses the properties of the white matter tissue along the major white matter bundles
#
# ![](images/tractometry.jpg)
#
# We have implemented a pipeline for doing this called [pyAFQ](https://yeatmanlab.github.io/pyAFQ) and we ran it on the 1,041 HCP subjects that have complete dMRI scans.
#
# These derivatives are available through the [Open Neurodata project](https://neurodata.io/project/ocp/) (not to be confused with OpenNeuro!)

# %%
from cloudpathlib import S3Path, S3Client

# Create a client that uses our cache path and that does not try to
# authenticate with S3.
client = S3Client(
    local_cache_dir=cache_path,
    no_sign_request=True)

# Now, create a cloudpath for the open neurodata's S3 bucket:
hcp_derivs_path = S3Path(
    "s3://open-neurodata/rokem/hcp1200/afq",
    client=client)

# %%
crawl(hcp_derivs_path / "sub-100206")
# Out:
# sub-100206
#    ses-01
#       ROIs
#          sub-100206_dwi_desc-ROI-ARC_L-1-include.json
#          sub-100206_dwi_desc-ROI-ARC_L-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-ARC_L-2-include.json
#          sub-100206_dwi_desc-ROI-ARC_L-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-ARC_R-1-include.json
#          sub-100206_dwi_desc-ROI-ARC_R-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-ARC_R-2-include.json
#          sub-100206_dwi_desc-ROI-ARC_R-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-ATR_L-1-include.json
#          sub-100206_dwi_desc-ROI-ATR_L-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-ATR_L-2-include.json
#          sub-100206_dwi_desc-ROI-ATR_L-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-ATR_R-1-include.json
#          sub-100206_dwi_desc-ROI-ATR_R-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-ATR_R-2-include.json
#          sub-100206_dwi_desc-ROI-ATR_R-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-AntFrontal-1-include.json
#          sub-100206_dwi_desc-ROI-AntFrontal-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-AntFrontal-2-include.json
#          sub-100206_dwi_desc-ROI-AntFrontal-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-AntFrontal-3-include.json
#          sub-100206_dwi_desc-ROI-AntFrontal-3-include.nii.gz
#          sub-100206_dwi_desc-ROI-CGC_L-1-include.json
#          sub-100206_dwi_desc-ROI-CGC_L-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-CGC_L-2-include.json
#          sub-100206_dwi_desc-ROI-CGC_L-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-CGC_R-1-include.json
#          sub-100206_dwi_desc-ROI-CGC_R-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-CGC_R-2-include.json
#          sub-100206_dwi_desc-ROI-CGC_R-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-CST_L-1-include.json
#          sub-100206_dwi_desc-ROI-CST_L-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-CST_L-2-include.json
#          sub-100206_dwi_desc-ROI-CST_L-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-CST_R-1-include.json
#          sub-100206_dwi_desc-ROI-CST_R-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-CST_R-2-include.json
#          sub-100206_dwi_desc-ROI-CST_R-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-IFO_L-1-include.json
#          sub-100206_dwi_desc-ROI-IFO_L-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-IFO_L-2-include.json
#          sub-100206_dwi_desc-ROI-IFO_L-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-IFO_R-1-include.json
#          sub-100206_dwi_desc-ROI-IFO_R-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-IFO_R-2-include.json
#          sub-100206_dwi_desc-ROI-IFO_R-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-ILF_L-1-include.json
#          sub-100206_dwi_desc-ROI-ILF_L-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-ILF_L-2-include.json
#          sub-100206_dwi_desc-ROI-ILF_L-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-ILF_R-1-include.json
#          sub-100206_dwi_desc-ROI-ILF_R-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-ILF_R-2-include.json
#          sub-100206_dwi_desc-ROI-ILF_R-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-Motor-1-include.json
#          sub-100206_dwi_desc-ROI-Motor-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-Motor-2-include.json
#          sub-100206_dwi_desc-ROI-Motor-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-Motor-3-include.json
#          sub-100206_dwi_desc-ROI-Motor-3-include.nii.gz
#          sub-100206_dwi_desc-ROI-Occipital-1-include.json
#          sub-100206_dwi_desc-ROI-Occipital-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-Occipital-2-include.json
#          sub-100206_dwi_desc-ROI-Occipital-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-Occipital-3-include.json
#          sub-100206_dwi_desc-ROI-Occipital-3-include.nii.gz
#          sub-100206_dwi_desc-ROI-Orbital-1-include.json
#          sub-100206_dwi_desc-ROI-Orbital-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-Orbital-2-include.json
#          sub-100206_dwi_desc-ROI-Orbital-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-Orbital-3-include.json
#          sub-100206_dwi_desc-ROI-Orbital-3-include.nii.gz
#          sub-100206_dwi_desc-ROI-PostParietal-1-include.json
#          sub-100206_dwi_desc-ROI-PostParietal-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-PostParietal-2-include.json
#          sub-100206_dwi_desc-ROI-PostParietal-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-PostParietal-3-include.json
#          sub-100206_dwi_desc-ROI-PostParietal-3-include.nii.gz
#          sub-100206_dwi_desc-ROI-SLF_L-1-include.json
#          sub-100206_dwi_desc-ROI-SLF_L-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-SLF_L-2-include.json
#          sub-100206_dwi_desc-ROI-SLF_L-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-SLF_L-3-exclude.json
#          sub-100206_dwi_desc-ROI-SLF_L-3-exclude.nii.gz
#          sub-100206_dwi_desc-ROI-SLF_R-1-include.json
#          sub-100206_dwi_desc-ROI-SLF_R-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-SLF_R-2-include.json
#          sub-100206_dwi_desc-ROI-SLF_R-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-SLF_R-3-exclude.json
#          sub-100206_dwi_desc-ROI-SLF_R-3-exclude.nii.gz
#          sub-100206_dwi_desc-ROI-SupFrontal-1-include.json
#          sub-100206_dwi_desc-ROI-SupFrontal-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-SupFrontal-2-include.json
#          sub-100206_dwi_desc-ROI-SupFrontal-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-SupFrontal-3-include.json
#          sub-100206_dwi_desc-ROI-SupFrontal-3-include.nii.gz
#          sub-100206_dwi_desc-ROI-SupParietal-1-include.json
#          sub-100206_dwi_desc-ROI-SupParietal-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-SupParietal-2-include.json
#          sub-100206_dwi_desc-ROI-SupParietal-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-SupParietal-3-include.json
#          sub-100206_dwi_desc-ROI-SupParietal-3-include.nii.gz
#          sub-100206_dwi_desc-ROI-Temporal-1-include.json
#          sub-100206_dwi_desc-ROI-Temporal-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-Temporal-2-include.json
#          sub-100206_dwi_desc-ROI-Temporal-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-Temporal-3-include.json
#          sub-100206_dwi_desc-ROI-Temporal-3-include.nii.gz
#          sub-100206_dwi_desc-ROI-UNC_L-1-include.json
#          sub-100206_dwi_desc-ROI-UNC_L-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-UNC_L-2-include.json
#          sub-100206_dwi_desc-ROI-UNC_L-2-include.nii.gz
#          sub-100206_dwi_desc-ROI-UNC_R-1-include.json
#          sub-100206_dwi_desc-ROI-UNC_R-1-include.nii.gz
#          sub-100206_dwi_desc-ROI-UNC_R-2-include.json
#          sub-100206_dwi_desc-ROI-UNC_R-2-include.nii.gz
#       viz_bundles
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_ARC_L_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_ARC_L_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_ARC_R_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_ARC_R_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_ATR_L_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_ATR_L_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_ATR_R_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_ATR_R_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_AntFrontal_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_AntFrontal_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_CGC_L_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_CGC_L_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_CGC_R_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_CGC_R_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_CST_L_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_CST_L_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_CST_R_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_CST_R_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_IFO_L_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_IFO_L_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_IFO_R_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_IFO_R_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_ILF_L_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_ILF_L_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_ILF_R_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_ILF_R_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_Motor_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_Motor_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_Occipital_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_Occipital_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_Orbital_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_Orbital_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_PostParietal_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_PostParietal_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_SLF_L_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_SLF_L_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_SLF_R_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_SLF_R_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_SupFrontal_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_SupFrontal_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_SupParietal_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_SupParietal_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_Temporal_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_Temporal_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_UNC_L_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_UNC_L_viz.html
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_UNC_R_viz.gif
#          sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_UNC_R_viz.html
#       sub-100206_dwi_b0.json
#       sub-100206_dwi_b0.nii.gz
#       sub-100206_dwi_brain_mask.json
#       sub-100206_dwi_brain_mask.nii.gz
#       sub-100206_dwi_mapping_from-DWI_to_MNI_xfm.nii.gz
#       sub-100206_dwi_mapping_reg.json
#       sub-100206_dwi_model-CSD_APM.json
#       sub-100206_dwi_model-CSD_APM.nii.gz
#       sub-100206_dwi_model-CSD_diffmodel.json
#       sub-100206_dwi_model-CSD_diffmodel.nii.gz
#       sub-100206_dwi_model-DKI_AWF.json
#       sub-100206_dwi_model-DKI_AWF.nii.gz
#       sub-100206_dwi_model-DKI_FA.json
#       sub-100206_dwi_model-DKI_FA.nii.gz
#       sub-100206_dwi_model-DKI_MD.json
#       sub-100206_dwi_model-DKI_MD.nii.gz
#       sub-100206_dwi_model-DKI_MK.json
#       sub-100206_dwi_model-DKI_MK.nii.gz
#       sub-100206_dwi_model-DKI_diffmodel.json
#       sub-100206_dwi_model-DKI_diffmodel.nii.gz
#       sub-100206_dwi_model-DTI_FA.json
#       sub-100206_dwi_model-DTI_FA.nii.gz
#       sub-100206_dwi_model-DTI_diffmodel.json
#       sub-100206_dwi_model-DTI_diffmodel.nii.gz
#       sub-100206_dwi_prealign_from-DWI_to-MNI_xfm.json
#       sub-100206_dwi_prealign_from-DWI_to-MNI_xfm.npy
#       sub-100206_dwi_seed_mask.json
#       sub-100206_dwi_seed_mask.nii.gz
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq-clean_tractography.json
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq-clean_tractography.trk
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq-clean_tractography.trx
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_awf_profile_plots.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_awf_profile_plots.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_awf_profile_plots_AntFrontal.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_awf_profile_plots_AntFrontal.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_awf_profile_plots_Motor.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_awf_profile_plots_Motor.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_awf_profile_plots_Occipital.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_awf_profile_plots_Occipital.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_awf_profile_plots_Orbital.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_awf_profile_plots_Orbital.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_awf_profile_plots_PostParietal.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_awf_profile_plots_PostParietal.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_awf_profile_plots_SupFrontal.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_awf_profile_plots_SupFrontal.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_awf_profile_plots_SupParietal.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_awf_profile_plots_SupParietal.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_awf_profile_plots_Temporal.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_awf_profile_plots_Temporal.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_fa_profile_plots.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_fa_profile_plots.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_fa_profile_plots_AntFrontal.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_fa_profile_plots_AntFrontal.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_fa_profile_plots_Motor.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_fa_profile_plots_Motor.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_fa_profile_plots_Occipital.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_fa_profile_plots_Occipital.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_fa_profile_plots_Orbital.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_fa_profile_plots_Orbital.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_fa_profile_plots_PostParietal.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_fa_profile_plots_PostParietal.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_fa_profile_plots_SupFrontal.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_fa_profile_plots_SupFrontal.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_fa_profile_plots_SupParietal.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_fa_profile_plots_SupParietal.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_fa_profile_plots_Temporal.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_fa_profile_plots_Temporal.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_md_profile_plots.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_md_profile_plots.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_md_profile_plots_AntFrontal.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_md_profile_plots_AntFrontal.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_md_profile_plots_Motor.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_md_profile_plots_Motor.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_md_profile_plots_Occipital.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_md_profile_plots_Occipital.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_md_profile_plots_Orbital.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_md_profile_plots_Orbital.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_md_profile_plots_PostParietal.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_md_profile_plots_PostParietal.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_md_profile_plots_SupFrontal.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_md_profile_plots_SupFrontal.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_md_profile_plots_SupParietal.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_md_profile_plots_SupParietal.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_md_profile_plots_Temporal.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_md_profile_plots_Temporal.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_mk_profile_plots.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_mk_profile_plots.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_mk_profile_plots_AntFrontal.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_mk_profile_plots_AntFrontal.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_mk_profile_plots_Motor.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_mk_profile_plots_Motor.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_mk_profile_plots_Occipital.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_mk_profile_plots_Occipital.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_mk_profile_plots_Orbital.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_mk_profile_plots_Orbital.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_mk_profile_plots_PostParietal.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_mk_profile_plots_PostParietal.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_mk_profile_plots_SupFrontal.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_mk_profile_plots_SupFrontal.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_mk_profile_plots_SupParietal.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_mk_profile_plots_SupParietal.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_mk_profile_plots_Temporal.png
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_dki_mk_profile_plots_Temporal.svg
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_profile_plots.json
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_profiles.csv
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_profiles.json
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_sl_count.csv
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_sl_count.json
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_tractography.json
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_tractography.trk
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_viz.gif
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_viz.html
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_viz.json
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_vizIndiv.json
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob_tractography.json
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob_tractography.trk
#       sub-100206_dwi_space-RASMM_model-CSD_desc-prob_tractography.trx
#       sub-100206_dwi_stop_mask.json
#       sub-100206_dwi_stop_mask.nii.gz

# %%
import pandas as pd

# %%
tract_profiles = pd.read_csv(hcp_derivs_path / "sub-100206" / "ses-01" / "sub-100206_dwi_space-RASMM_model-CSD_desc-prob-afq_profiles.csv")

# %%
tract_profiles
# Out:
#       Unnamed: 0   tractID  nodeID    dki_fa    dki_md    dki_mk   dki_awf
# 0              0     ATR_R       0  0.246921  0.000868  0.501324  0.199983
# 1              1     ATR_R       1  0.300765  0.000880  0.640582  0.239359
# 2              2     ATR_R       2  0.339260  0.000917  0.759825  0.271670
# 3              3     ATR_R       3  0.383969  0.000932  0.830803  0.298200
# 4              4     ATR_R       4  0.422217  0.000927  0.881660  0.320883
# ...          ...       ...     ...       ...       ...       ...       ...
# 2395        2395  Temporal      95  0.476688  0.000947  1.062110  0.373244
# 2396        2396  Temporal      96  0.453998  0.000959  1.051261  0.363928
# 2397        2397  Temporal      97  0.440950  0.000986  1.026778  0.351072
# 2398        2398  Temporal      98  0.393467  0.001040  0.958425  0.320734
# 2399        2399  Temporal      99  0.257552  0.001174  0.810534  0.255744
#
# [2400 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(tract_profiles[tract_profiles["tractID"] == "CST_L"]["dki_fa"].values)
ax.set_xlabel("Node")
ax.set_ylabel("FA")
# Out:
# Text(0, 0.5, 'FA')
